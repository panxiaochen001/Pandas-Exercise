# %% [markdown]
# <a href="https://colab.research.google.com/github/panxiaochen001/Pandas-Exercise/blob/main/Intro_to_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Numpy - List to Array

# %%
a_list = [1,2,3,4,5,6,7]

# %%
type(a_list)
# Out:
# list

# %%
b_array = np.array([1,2,3,4,5,6,7])

# %%
type(b_array)
# Out:
# numpy.ndarray

# %% [markdown]
# Why array not list? ----- the speed of operation

# %% [markdown]
# Example 1: Using list to do the muplication (multiply 10 for each element)

# %%
arr = []

for i in a_list:
  arr.append(i * 10)

arr
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
list(map(lambda i:i*10,a_list))
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
[i * 10 for i in a_list]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %% [markdown]
# Example 2: Using array to do the muplication (multiply 10 for each element)

# %%
b_array*10
# Out:
# array([10, 20, 30, 40, 50, 60, 70])
